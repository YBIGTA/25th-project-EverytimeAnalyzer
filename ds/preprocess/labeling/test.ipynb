# %%
import sys
import os
import pandas as pd

sys.path.append(os.path.dirname(os.path.abspath(os.getcwd())))

from data_processing import *
from text_processing import normalize_text
from embedding import load_model, generate_embedding

# %%
# TODO: flag_sentences 전처리 및 embedding vector 생성

def process_flag_sentences(input_file: str, output_file: str) -> pd.DataFrame:
    """
    텍스트 파일 읽어와서 전처리 후 embedding vector 생성
    Args:
        - input_file: 입력 텍스트 파일 경로
        - output_file: 출력 CSV 파일 경로
    """
    data = []
    
    # 텍스트 파일을 읽어서 처리
    with open(input_file, 'r', encoding='utf-8') as file:
        for line in file:
            # 각 줄에서 첫 번째 쉼표만 기준으로 분리
            topic, sentence = line.split(',', 1)
            data.append([topic.strip(), sentence.strip()])

    # DataFrame으로 변환
    df = pd.DataFrame(data, columns=["topic", "sentence"])

    # 문장 정규화
    df['normalized_sentence'] = df['sentence'].apply(normalize_text)
    
    # 문장별 임베딩 생성
    model = load_model()
    df['embedding'] = df['normalized_sentence'].apply(
        lambda sentence: generate_embedding(model, sentence)
    )
    
    # 결과를 CSV 파일로 저장
    df.to_csv(output_file, index=False)
    
    return df

df_result = process_flag_sentences('flag_sentences.txt', 'flag_sentences_embedding.csv')
df_result
# Out:
# /Users/jieunpark/.local/share/virtualenvs/ds-J7fYfd54/lib/python3.11/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
#               topic                                           sentence  \
# 0             수업 내용  그리스 비극 작품에 대해 교수님이 제시해주시는 몇 가지 주제에 대해 토론하며 그리스...
# 1             수업 내용  최적화와 미분방정식에 대해 잘 배울 수 있었고 거경동, 금계 듣기전에 들으면 좋을 ...
# 2             수업 내용   정말 재정학을 쉽게 공부할 수 있고 기본 베이스 탄탄하면 충분히 따라갈 수 있는 수업.
# 3             수업 내용  수업내용은 공공재가 포함된 최적화된 자원의 배분, 학부생 수준의 여러 보험관련 모델...
# 4             수업 내용   전선 들으면서 많이 쓰게 될 행렬 계산이나 분해 등 선형대수의 기초적인 내용을 배웁니다
# 5                로드                        개인발표 한 번 있는데 부담되지 않는 정도입니다.
# 6                로드        완전 좋아요!! 부담이 안 가는 수업이 하나 있어서 편안한 한 학기 보냈습니다
# 7                로드                                     방학때 예습하고 오면 좋음
# 8                로드                                 9학점 정도의 로드라고 생각합니다
# 9                로드                           그리고 과제가 귀찮고 양만 많은 과제입니다.
# 10  교수님 강의스타일 및 강의력  영강 듣는 친구는 교수님께서 영어로는 하고 싶은 말을 100% 전달하시지 못하셔서 ...
# 11  교수님 강의스타일 및 강의력  교수님께서 교육에 열정도 넘치시고, 젊으신만큼 에너지도 넘치셔서 수업 텐션도 상당히...
# 12  교수님 강의스타일 및 강의력                            경우리 그저 빛 일단 강의력 너무 좋으심.
# 13  교수님 강의스타일 및 강의력      이제껏 전선을 꽤나 들어보았지만 그 중 손에 꼽힐 정도로 강의력이 매우 훌륭하시다
# 14  교수님 강의스타일 및 강의력                                강의력은.. 기대하지 말고 들어야함
# 15        시험 출제 스타일         기출연계 많이 되지만, 기출에서 나왔던 개념의 다른 부분이 출제 될 수 있다
# 16        시험 출제 스타일  시험은 감상시험과 이론시험으로 나뉘는데 체감상 이론은 99% 족보를 탔어서 크게 부...
# 17        시험 출제 스타일  그래도 기말 난이도는 꽤 있는 편이었고 extra credit을 위한 Self Qn...
# 18        시험 출제 스타일                           중간 조지면 기말 만회는 안되니까 철회해야함
# 19        시험 출제 스타일                                   서술형 채점 기준을 모르겠음…
# 20               학점  과제의 비중이 매우 높아요 시험점수 차이도 어느정도 있지만 과제 죽 쑤면 에이 받기 힘듬
# 21               학점  1차중간 평균 2차중간 평균 -5 기말 평균 +20 상위 30퍼 성적보다 10점 정...
# 22               학점                                      학점을 애초에 잘주시는듯
# 23               학점  기말 조금만 잘 봤어도 에이쁠 나왔을 것 같아서 아쉽긴 하지만 이것도 엄청 후하게 ...
# 24               학점  지난 학기처럼 학점을 뿌리신다 이런 느낌은 전혀 없었지만 그냥 무난한 미시학 수업이...
#
#                                   normalized_sentence  \
# 0   그리스 비극 작품에 대해 교수님이 제시해 주시는 몇 가지 주제에 대해 토론하며 그리...
# 1   최적화와 미분방정식에 대해 잘 배울 수 있었고 거 경동, 금계 듣기 전에 들으면 좋...
# 2    정말 재정학을 쉽게 공부할 수 있고 기본 베이스 탄탄하면 충분히 따라갈 수 있는 수업.
# 3   수업내용은 공공재가 포함된 최적화된 자원의 배분, 학부생 수준의 여러 보험 관련 모...
# 4    전선 들으면서 많이 쓰게 될 행렬 계산이나 분해 등 선형대수의 기초적인 내용을 배웁니다
# 5                         개인발표 한 번 있는데 부담되지 않는 정도입니다.
# 6         정말 좋아요!! 부담이 안 가는 수업이 하나 있어서 편안한 한 학기 보냈습니다
# 7                                     방학 때 예습하고 오면 좋음
# 8                                  9학점 정도의 로드라고 생각합니다
# 9                            그리고 과제가 귀찮고 양만 많은 과제입니다.
# 10  영강 듣는 친구는 교수님께서 영어로는 하고 싶은 말을 100 전달하시지 못하셔서 답...
# 11  교수님께서 교육에 열정도 넘치시고, 젊으신 만큼 에너지도 넘치셔서 수업 텐션도 상당...
# 12                           경우 미 그저 빛 일단 강의력 너무 좋으심.
# 13      이제껏 전선을 꽤나 들어보았지만 그중 손에 꼽힐 정도로 강 위력이 매우 훌륭하시다
# 14                              강 위력은.. 기대하지 말고 들어야 함
# 15         기출 연계 많이 되지만, 기출에서 나왔던 개념의 다른 부분이 출제될 수 있다
# 16  시험은 감상 시험과 이론시험으로 나뉘는데 체감상 이론은 99 족보를 타서 크게 부담...
# 17  그래도 기말 난이도는 꽤 있는 편이었고 extra credit을 위한 Self Qn...
# 18                          중간 조지면 기말 만회는 안되니까 철회해야 함
# 19                                    서술형 채점 기준을 모르겠음
# 20  과제의 비중이 매우 높아요 시험 점수 차이도 어느 정도 있지만 과제 죽 쑤면 에이 ...
# 21  1차 중간 평균 2차 중간 평균 5 기말 평균 20 상위 30퍼 성적보다 10점 정...
# 22                                    학점을 애초에 잘 주시는 듯
# 23  기말 조금만 잘 봤어도 이쁠 나왔을 것 같아서 아쉽긴 하지만 이것도 엄청 후하게 주...
# 24  지난 학기처럼 학점을 뿌리신다 이런 느낌은 전혀 없었지만 그냥 무난한 이 시학 수업...
#
#                                             embedding
# 0   [-0.20224088, -0.15938044, -1.2832941, -0.1154...
# 1   [0.43971437, -0.32195133, 0.4378168, -0.060926...
# 2   [0.46927884, 0.15568912, 0.054435045, 0.028569...
# 3   [0.43316495, -0.41206998, -0.015462182, -0.228...
# 4   [0.20476538, -0.13527519, -0.20354806, -0.7453...
# 5   [0.41946656, -0.23722848, -0.16952115, -0.4319...
# 6   [0.20082153, 0.07706957, 0.1238373, -0.0154489...
# 7   [0.39516202, -0.45368055, -0.387158, 0.2297077...
# 8   [0.42097637, 0.39000615, -0.25041512, -0.77401...
# 9   [-0.44393656, -0.36779192, 0.3453805, 0.041896...
# 10  [-0.15001807, 0.044443537, -0.18010496, -0.367...
# 11  [-0.71284103, 0.10905801, -0.20621647, -0.0648...
# 12  [0.24892591, 0.21881735, 0.1226588, -0.2370759...
# 13  [-0.21692665, -0.089738645, -0.8470065, -0.383...
# 14  [0.38685206, -0.2329305, 0.117045246, -0.67213...
# 15  [-0.07345056, -0.19064145, 0.055736694, -0.628...
# 16  [0.037419707, -0.26764652, 0.09794429, -0.6612...
# 17  [-0.36092666, -0.18121393, -0.34553802, -0.604...
# 18  [-0.2827287, -0.065444686, 0.13522127, 0.32018...
# 19  [-0.19497702, 0.44439775, -0.36665225, -0.8837...
# 20  [-0.25241247, 0.100909434, -0.13381962, -0.725...
# 21  [0.34931767, 0.2868176, -0.16372575, -0.396269...
# 22  [-0.21367705, 0.09195151, 0.26377344, -0.02459...
# 23  [-0.08489813, 0.03279715, -0.34112206, -0.1878...
# 24  [-0.104252115, 0.044533152, -0.17275916, -0.10...

# %%
# TODO: 강의평 각 문장들과 flag_sentences의 5개 토픽 * 5개 문장 = 25개 문장 간의 manhattan distance 계산 -> 18000 * 25개의 distance matrix 생성
def manhattan_distance(v1, v2):
    return sum(abs(v1 - v2))

def calculate_distance_matrix(review_sentences, flag_sentences):
    distance_matrix = []
    for i in range(len(review_sentences)):
        distances = []
        for j in range(len(flag_sentences)):
            distances.append(manhattan_distance(review_sentences['embedding'][i], flag_sentences['embedding'][j]))
        distance_matrix.append(distances)
    return pd.DataFrame(distance_matrix, index=review_sentences.sentence, columns=flag_sentences.sentence)

# %%
# TODO: 각 문장들과 토픽별 5개 문장 간의 유사도 중 최소값을 각 문장의 토픽 유사도로 사용 -> 18000 * 5개의 similarity matrix 생성

# %%
# TODO: 토픽별로 유사도 상위 250개 문장 추출 후 중복 제거 -> max 1250개 문장과 해당 문장의 소속 토픽 유사도 저장
